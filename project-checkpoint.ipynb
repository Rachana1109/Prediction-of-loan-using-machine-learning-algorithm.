# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("train_loanPrediction.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-4add79e59e22> in <module>
# ----> 1 df=pd.read_csv("train_loanPrediction.csv")
#
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(filepath_or_buffer, **kwds)
#     458
#     459     if chunksize or iterator:
#
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     812             self.options["has_index_names"] = kwds["has_index_names"]
#     813
# --> 814         self._engine = self._make_engine(self.engine)
#     815
#     816     def close(self):
#
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1043             )
#    1044         # error: Too many arguments for "ParserBase"
# -> 1045         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1046
#    1047     def _failover_to_python(self):
#
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1860
#    1861         # open handles
# -> 1862         self._open_handles(src, kwds)
#    1863         assert self.handles is not None
#    1864         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1355         Let the readers open IOHanldes after they are done with their potential raises.
#    1356         """
# -> 1357         self.handles = get_handle(
#    1358             src,
#    1359             "r",
#
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train_loanPrediction.csv'

# %%
df.head(50)
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001002    Male      No         0.0      Graduate            No
# 1   LP001003    Male     Yes         1.0      Graduate            No
# 2   LP001005    Male     Yes         0.0      Graduate           Yes
# 3   LP001006    Male     Yes         0.0  Not Graduate            No
# 4   LP001008    Male      No         0.0      Graduate            No
# 5   LP001011    Male     Yes         2.0      Graduate           Yes
# 6   LP001013    Male     Yes         0.0  Not Graduate            No
# 7   LP001014    Male     Yes         3.0      Graduate            No
# 8   LP001018    Male     Yes         2.0      Graduate            No
# 9   LP001020    Male     Yes         1.0      Graduate            No
# 10  LP001024    Male     Yes         2.0      Graduate            No
# 11  LP001027    Male     Yes         2.0      Graduate           NaN
# 12  LP001028    Male     Yes         2.0      Graduate            No
# 13  LP001029    Male      No         0.0      Graduate            No
# 14  LP001030    Male     Yes         2.0      Graduate            No
# 15  LP001032    Male      No         0.0      Graduate            No
# 16  LP001034    Male      No         1.0  Not Graduate            No
# 17  LP001036  Female      No         0.0      Graduate            No
# 18  LP001038    Male     Yes         0.0  Not Graduate            No
# 19  LP001041    Male     Yes         0.0      Graduate           NaN
# 20  LP001043    Male     Yes         0.0  Not Graduate            No
# 21  LP001046    Male     Yes         1.0      Graduate            No
# 22  LP001047    Male     Yes         0.0  Not Graduate            No
# 23  LP001050     NaN     Yes         2.0  Not Graduate            No
# 24  LP001052    Male     Yes         1.0      Graduate           NaN
# 25  LP001066    Male     Yes         0.0      Graduate           Yes
# 26  LP001068    Male     Yes         0.0      Graduate            No
# 27  LP001073    Male     Yes         2.0  Not Graduate            No
# 28  LP001086    Male      No         0.0  Not Graduate            No
# 29  LP001087  Female      No         2.0      Graduate           NaN
# 30  LP001091    Male     Yes         1.0      Graduate           NaN
# 31  LP001095    Male      No         0.0      Graduate            No
# 32  LP001097    Male      No         1.0      Graduate           Yes
# 33  LP001098    Male     Yes         0.0      Graduate            No
# 34  LP001100    Male      No         3.0      Graduate            No
# 35  LP001106    Male     Yes         0.0      Graduate            No
# 36  LP001109    Male     Yes         0.0      Graduate            No
# 37  LP001112  Female     Yes         0.0      Graduate            No
# 38  LP001114    Male      No         0.0      Graduate            No
# 39  LP001116    Male      No         0.0  Not Graduate            No
# 40  LP001119    Male      No         0.0      Graduate            No
# 41  LP001120    Male      No         0.0      Graduate            No
# 42  LP001123    Male     Yes         0.0      Graduate            No
# 43  LP001131    Male     Yes         0.0      Graduate            No
# 44  LP001136    Male     Yes         0.0  Not Graduate           Yes
# 45  LP001137  Female      No         0.0      Graduate            No
# 46  LP001138    Male     Yes         1.0      Graduate            No
# 47  LP001144    Male     Yes         0.0      Graduate            No
# 48  LP001146  Female     Yes         0.0      Graduate            No
# 49  LP001151  Female      No         0.0      Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              5849                0.0         NaN             360.0
# 1              4583             1508.0       128.0             360.0
# 2              3000                0.0        66.0             360.0
# 3              2583             2358.0       120.0             360.0
# 4              6000                0.0       141.0             360.0
# 5              5417             4196.0       267.0             360.0
# 6              2333             1516.0        95.0             360.0
# 7              3036             2504.0       158.0             360.0
# 8              4006             1526.0       168.0             360.0
# 9             12841            10968.0       349.0             360.0
# 10             3200              700.0        70.0             360.0
# 11             2500             1840.0       109.0             360.0
# 12             3073             8106.0       200.0             360.0
# 13             1853             2840.0       114.0             360.0
# 14             1299             1086.0        17.0             120.0
# 15             4950                0.0       125.0             360.0
# 16             3596                0.0       100.0             240.0
# 17             3510                0.0        76.0             360.0
# 18             4887                0.0       133.0             360.0
# 19             2600             3500.0       115.0               NaN
# 20             7660                0.0       104.0             360.0
# 21             5955             5625.0       315.0             360.0
# 22             2600             1911.0       116.0             360.0
# 23             3365             1917.0       112.0             360.0
# 24             3717             2925.0       151.0             360.0
# 25             9560                0.0       191.0             360.0
# 26             2799             2253.0       122.0             360.0
# 27             4226             1040.0       110.0             360.0
# 28             1442                0.0        35.0             360.0
# 29             3750             2083.0       120.0             360.0
# 30             4166             3369.0       201.0             360.0
# 31             3167                0.0        74.0             360.0
# 32             4692                0.0       106.0             360.0
# 33             3500             1667.0       114.0             360.0
# 34            12500             3000.0       320.0             360.0
# 35             2275             2067.0         NaN             360.0
# 36             1828             1330.0       100.0               NaN
# 37             3667             1459.0       144.0             360.0
# 38             4166             7210.0       184.0             360.0
# 39             3748             1668.0       110.0             360.0
# 40             3600                0.0        80.0             360.0
# 41             1800             1213.0        47.0             360.0
# 42             2400                0.0        75.0             360.0
# 43             3941             2336.0       134.0             360.0
# 44             4695                0.0        96.0               NaN
# 45             3410                0.0        88.0               NaN
# 46             5649                0.0        44.0             360.0
# 47             5821                0.0       144.0             360.0
# 48             2645             3440.0       120.0             360.0
# 49             4000             2275.0       144.0             360.0
#
#     Credit_History Property_Area Loan_Status
# 0              1.0         Urban           Y
# 1              1.0         Rural           N
# 2              1.0         Urban           Y
# 3              1.0         Urban           Y
# 4              1.0         Urban           Y
# 5              1.0         Urban           Y
# 6              1.0         Urban           Y
# 7              0.0     Semiurban           N
# 8              1.0         Urban           Y
# 9              1.0     Semiurban           N
# 10             1.0         Urban           Y
# 11             1.0         Urban           Y
# 12             1.0         Urban           Y
# 13             1.0         Rural           N
# 14             1.0         Urban           Y
# 15             1.0         Urban           Y
# 16             NaN         Urban           Y
# 17             0.0         Urban           N
# 18             1.0         Rural           N
# 19             1.0         Urban           Y
# 20             0.0         Urban           N
# 21             1.0         Urban           Y
# 22             0.0     Semiurban           N
# 23             0.0         Rural           N
# 24             NaN     Semiurban           N
# 25             1.0     Semiurban           Y
# 26             1.0     Semiurban           Y
# 27             1.0         Urban           Y
# 28             1.0         Urban           N
# 29             1.0     Semiurban           Y
# 30             NaN         Urban           N
# 31             1.0         Urban           N
# 32             1.0         Rural           N
# 33             1.0     Semiurban           Y
# 34             1.0         Rural           N
# 35             1.0         Urban           Y
# 36             0.0         Urban           N
# 37             1.0     Semiurban           Y
# 38             1.0         Urban           Y
# 39             1.0     Semiurban           Y
# 40             1.0         Urban           N
# 41             1.0         Urban           Y
# 42             NaN         Urban           Y
# 43             1.0     Semiurban           Y
# 44             1.0         Urban           Y
# 45             1.0         Urban           Y
# 46             1.0         Urban           Y
# 47             1.0         Urban           Y
# 48             0.0         Urban           N
# 49             1.0     Semiurban           Y

# %%
df1=df.dropna()

# %%
df2=df1.drop(["Loan_ID"],axis=1)

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()

# %%
df2['LGender'] = le.fit_transform(df2['Gender'].values.reshape(-1,1).ravel())
df2['LMarried']=le.fit_transform(df2['Married'].values.reshape(-1,1).ravel())
df2['LSelf_Employed']=le.fit_transform(df2["Self_Employed"].values.reshape(-1,1).ravel())
#df2['LLoan_Status']=le.fit_transform(df2["Loan_Status"].values.reshape(-1,1).ravel())
df2['LEducation']=le.fit_transform(df2["Education"].values.reshape(-1,1).ravel())
df2['LProperty_Area']=le.fit_transform(df2["Property_Area"].values.reshape(-1,1).ravel())

# %%
df2=df2.drop(["Self_Employed"],axis=1)
#df2=df2.drop(["Loan_Status"],axis=1)
df2=df2.drop(["Property_Area"],axis=1)
df2=df2.drop(["Married"],axis=1)
df2=df2.drop(["Gender"],axis=1)
df2=df2.drop(["Education"],axis=1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
x=df2.iloc[:,df2.columns !='Loan_Status']
y=df2.iloc[:,df2.columns =='Loan_Status']

# %%
x.head(1)
# Out:
#    Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 1         1.0             4583             1508.0       128.0
#
#    Loan_Amount_Term  Credit_History  LGender  LMarried  LSelf_Employed  \
# 1             360.0             1.0        1         1               0
#
#    LEducation  LProperty_Area
# 1           0               0

# %%
y.head(1)
# Out:
#   Loan_Status
# 1           N

# %%
lr=LogisticRegression(class_weight='balanced')

lr.fit(x,y)
y_predict=lr.predict(x)
# Out:
# c:\users\harshini reddy\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y,y_predict)
# Out:
# 0.775

# %%
df2.head(7)
# Out:
#    Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 1         1.0             4583             1508.0       128.0
# 2         0.0             3000                0.0        66.0
# 3         0.0             2583             2358.0       120.0
# 4         0.0             6000                0.0       141.0
# 5         2.0             5417             4196.0       267.0
# 6         0.0             2333             1516.0        95.0
# 7         3.0             3036             2504.0       158.0
#
#    Loan_Amount_Term  Credit_History Loan_Status  LGender  LMarried  \
# 1             360.0             1.0           N        1         1
# 2             360.0             1.0           Y        1         1
# 3             360.0             1.0           Y        1         1
# 4             360.0             1.0           Y        1         0
# 5             360.0             1.0           Y        1         1
# 6             360.0             1.0           Y        1         1
# 7             360.0             0.0           N        1         1
#
#    LSelf_Employed  LEducation  LProperty_Area
# 1               0           0               0
# 2               1           0               2
# 3               0           1               2
# 4               0           0               2
# 5               1           0               2
# 6               0           1               2
# 7               0           0               1

# %%
lr.predict([[3.0,3036,2504.0,158.0,360.0,0.0,1,1,0,0,1]])[0]
# Out:
# 'N'

# %%
import pickle

# %%
with open('project1.pkl','wb') as f:
    pickle.dump(lr,f)

# %%
df2['Loan_Status'].value_counts()
# Out:
# Y    332
# N    148
# Name: Loan_Status, dtype: int64

# %%
df2.head()
# Out:
#    Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 1         1.0             4583             1508.0       128.0
# 2         0.0             3000                0.0        66.0
# 3         0.0             2583             2358.0       120.0
# 4         0.0             6000                0.0       141.0
# 5         2.0             5417             4196.0       267.0
#
#    Loan_Amount_Term  Credit_History Loan_Status  LGender  LMarried  \
# 1             360.0             1.0           N        1         1
# 2             360.0             1.0           Y        1         1
# 3             360.0             1.0           Y        1         1
# 4             360.0             1.0           Y        1         0
# 5             360.0             1.0           Y        1         1
#
#    LSelf_Employed  LEducation  LProperty_Area
# 1               0           0               0
# 2               1           0               2
# 3               0           1               2
# 4               0           0               2
# 5               1           0               2

# %%
lr_model=pickle.load(open('project1.pkl','rb'))

lr_model.predict([[0.0,3000,0.0,66.0,360.0,1.0,1,1,1,0,2]])[0]
# Out:
# 'Y'
